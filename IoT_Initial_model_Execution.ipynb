# %% [markdown]
# <a href="https://colab.research.google.com/github/shivi13102/API-Projects/blob/main/IoT_Initial_model_Execution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the output CSV into a DataFrame
output = pd.read_csv("p2p_dataset_updated.csv")

# %%
# Rename columns
output.columns = ['X', 'Y', 'Scenario', 'Distance', 'Obstacles', 'Protocol', 'Power', 'Energy', 'RSSI']

# Convert relevant columns to numeric, ignoring errors
output_numeric = output.apply(pd.to_numeric, errors='coerce')

# Compute the correlation matrix
corr_matrix = output_numeric.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap with the 'RdBu' colormap to match your image
sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='RdBu', fmt='.2f', linewidths=0.5, annot_kws={"size": 10}, vmin=-1, vmax=1)

# Add title
plt.title("Correlation Matrix Heatmap")

# Show the plot
plt.show()
